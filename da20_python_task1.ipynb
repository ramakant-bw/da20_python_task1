# %%
# Special / Dunder Methods

#Variables

s = "hi"
greet = "welcome to my home"
call = "Hi are you there"
ask = "what is your name"
talk = "how are you doing"
help = "can i help you with something"
info = "do you need any information"
assist = "how can I assist you"
support = "let me know if you need support"
guide = "I can guide you through the process"
suggest = "may I suggest something"
         

#Add
print(s.__add__(" there"))
print(greet.__add__(" Rahul"))
print(s.__add__(" how are you"))
print(s.__add__(" what's up")) 
print(s.__add__(" may i help you")) 
print(s.__add__(" what`s going on")) 
print(s.__add__(" what do you want")) 
print(s.__add__(" where are you")) 
print(s.__add__(" when will you come"))
print(s.__add__(" are you ok")) 
print(s.__add__(" Welcome to my home"))

#Contain
print("hi".__contains__("h")) 
print("hi".__contains__("y "))  
print("Welcome back".__contains__("h"))  
print("where do you live".__contains__("live")) 
print("what is your name".__contains__("is")) 
print("My name is lucky".__contains__("lucky")) 
print("this is my home".__contains__("house"))  
print("can I come".__contains__("I")) 
print("where are they gone".__contains__("going"))  
print("is she going to office".__contains__("to"))     



#Equal
print("a".__eq__("a"))         
print(greet.__eq__("welcome to my home"))   
print(call.__eq__("Hi are you there"))     
print(ask.__eq__("what is your name"))    
print(talk.__eq__("how are you doing"))     
print(help.__eq__("can i help you with something"))       
print(info.__eq__("do you need any information"))       
print("assist".__eq__("how can I assist you"))       
print(support.__eq__("let me know if you need support")) 
print(guide.__eq__("I can guide you through the process")) 
print(suggest.__eq__("may I suggest something"))       




#Format
print("pi = {:.2f}".format(3.14159))
print("Hello, {}. Welcome!".format("Alice"))
print("Coordinates: {latitude}, {longitude}".format(latitude="37.24N", longitude    ="-115.81W"))
print("The {vehicle} is a {color} {type}.".format(vehicle="car", color="red", type="sedan")) 
print("The {0} is a {1} {2}.".format("bike", "blue", "mountain")) 
print("The {vehicle} is a {color} {type}.".format(vehicle="truck", color="black", type="pickup")) 
print("The {0} is a {1} {2}.".format("boat",    "white", "yacht"))  
print("The {vehicle} is a {color} {type}.".format(vehicle="plane", color="silver", type="jet"))  
print("The {0} is a {1} {2}.".format("scooter", "green", "electric"))  
print("The {vehicle} is a {color} {type}.".format(vehicle="bus", color="yellow", type="school")) 



#Greater Than Equal To
print("a".__ge__("A"))    
print((85).__ge__(85))
print((85).__ge__(80))
print((71).__ge__(85))
print((5).__ge__(85))
print((0).__ge__(-1))
print(("abc").__ge__("xyz"))
print(("1").__ge__("1"))
print((65).__ge__(65))
print((85).__ge__(8))




#Get Item
print(s.__getitem__(0))         
print(greet.__getitem__(3))     
print(call.__getitem__(5))      
print(ask.__getitem__(2))       
print(talk.__getitem__(4))      
print(help.__getitem__(7))      
print(info.__getitem__(10))     
print(assist.__getitem__(5))    
print(support.__getitem__(8))   
print(guide.__getitem__(6))     





#Greater Than
print("hello".__gt__("abc"))
print("hello".__gt__("abc"))        
print("10".__gt__("12"))      
print("zebra".__gt__("yak"))        
print("moon".__gt__("sun"))          
print("car".__gt__("bike"))         
print("0".__gt__("1"))          
print("ant".__gt__("antelope"))      
print("python".__gt__("java"))      
print("8".__gt__("7"))        
print("grape".__gt__("grapefruit"))  



#Hash
print(hash("hi")) 
print(hash("hi"))
print(hash("hello"))
print(hash("welcome"))
print(hash("python"))
print(hash("openai"))
print(hash("copilot"))
print(hash("hashing"))
print(hash("example"))
print(hash("string"))
print(hash("function")) 


#Iteraator 

iter_list = ["hi", "hello", "welcome", "python", "openai", "copilot", "hashing", "example", "string", "function"]

iterator = iter(iter_list)

print(iterator.__next__())
print(iterator.__next__())  
print(iterator.__next__())  
print(iterator.__next__())  
print(iterator.__next__())  
print(iterator.__next__())   
print(iterator.__next__())   
print(iterator.__next__())   
print(iterator.__next__())  
print(iterator.__next__()) 



#Less than or equal to
print("a".__le__("b"))  
print((1).__le__(2))      
print("10".__le__("2"))    
print("100".__le__("99"))   
print("5".__le__("5"))      
print("007".__le__("08"))   
print((2).__le__("200"))   
print((9).__le__(10))     
print((123).__le__("1234")) 
print((000).__le__(0))    
print("3".__le__("3"))          


#Len
print(len("hi"))  
print(len("hi"))            
print(len("hello world"))    
print(len("Python"))        
print(len("12345"))         
print(len(" "))                 
print(len([1, 2, 3]))        
print(len(["apple", "banana", "cherry"])) 
print(len([]))               
print(len((10, 20, 30)))     
print(len({"a", "b", "c"}))  


#less than
print("a".__lt__("b"))        
print("apple".__lt__("banana"))
print("cat".__lt__("car"))     
print("dog".__lt__("door"))   
print("zebra".__lt__("yak"))   
print("ant".__lt__("antelope"))
print("moon".__lt__("sun"))   
print("python".__lt__("java")) 
print("grape".__lt__("grapefruit"))
print("hello".__lt__("hello")) 




#Mod
print("Value %s".__mod__("X")) 
print("Hello %s".__mod__("World"))       
print("Age: %d".__mod__(30))                   
print("Price: %.2f".__mod__(19.99))              
print("Coordinates: (%d, %d)".__mod__((10, 20))) 
print("Name: %s, Score: %d".__mod__(("Alice", 95)))  
print("Value %s".__mod__("X"))
print("Hello %s".__mod__("World"))
print("Number: %s".__mod__(42))
print("Status: %s".__mod__("Active"))
print("User %s logged in".__mod__("Admin"))
print("ID: %s".__mod__(1001))              





#Mul
print("ha".__mul__(3))          
print("yo".__mul__(2))     
print("ok".__mul__(5))        
print("!".__mul__(10))         
print("na".__mul__(4))         
print("go".__mul__(3))       
print("hi".__mul__(6))         
print("bye".__mul__(2))      
print("wow".__mul__(3))        
print("echo".__mul__(2))       



#NotEqual
print("a".__ne__("b"))          
print("hello".__ne__("world"))  
print("cat".__ne__("cat"))       
print("dog".__ne__("Dog"))     
print("123".__ne__("1234"))     
print("apple".__ne__("APPLE"))  
print("yes".__ne__("no"))       
print("python".__ne__("python")) 
print("hi".__ne__("HI"))        
print("same".__ne__("same"))     



#string representation
print(repr("hi"))  
print(repr(42))    
print(repr(3.14))    
print(repr("hello\nworld"))
print(repr([1, 2, 3]))    
print(repr({"a": 1}))    
print(repr(True))            
print(repr(None))            
print(repr((1, "a", 3.5)))         
print(repr({"x": [1, 2], "y": "z"}))
print(repr("Line\nBreak"))          




#right-side modulo formatting
print("{0}%".__rmod__(50))      
print("Score: %d".__rmod__(95))       
print("Price: %.2f".__rmod__(19.99))     
print("Coordinates: (%d, %d)".__rmod__((10, 20)))  
print("User: %s, Age: %d".__rmod__(("Bob", 30)))
print("Temp: %.1f°C".__rmod__(36.6))     
print("ID: %05d".__rmod__(42))           
print("Hex: %x".__rmod__(255))           
print("Binary: %b".__rmod__(5))          




#right-side multiplication
print("ab".__rmul__(3))    
print("ha".__rmul__(5))    
print("yo".__rmul__(2))  
print("ok".__rmul__(4))      
print("na".__rmul__(6))          
print("go".__rmul__(3))    
print("hi".__rmul__(1))
print("bye".__rmul__(2))   
print("wow".__rmul__(0))          
print("echo".__rmul__(2))    



#memory size in bytes
print("hi".__sizeof__())               
print("hello".__sizeof__())           
print("".__sizeof__())                 
print("a" * (10).__sizeof__())        
print([1, 2, 3].__sizeof__())          
print((1, 2, 3).__sizeof__())          
print({"a": 1, "b": 2}.__sizeof__())   
print(set([1, 2, 3]).__sizeof__())
print((42).__sizeof__())                 
print((3.14).__sizeof__())            



#string representation 
print(str("hi"))     
print(str(42))       
print(str(3.14))       
print(str(True))       
print(str(None))       
print(str([1, 2, 3]))       
print(str((4, 5)))       
print(str({"a": 1}))       
print(str({1, 2, 3}))       
print(str("hello\nworld"))
